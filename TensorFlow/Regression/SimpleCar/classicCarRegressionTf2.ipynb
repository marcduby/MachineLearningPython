# %%
import tensorflow as tf 
import seaborn as sb 
import pandas as pd 
import sklearn as sk 
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

print("the tensorflow version is {}".format(tf.__version__))
print("the pandas version is {}".format(pd.__version__))
print("the sklearn version is {}".format(sk.__version__))
print("the seaborn version is {}".format(sb.__version__))
# Out:
# the tensorflow version is 2.1.0
# the pandas version is 1.0.3
# the sklearn version is 0.22.2.post1
# the seaborn version is 0.10.1

# %%
# get the file data
data_file = tf.keras.utils.get_file("auto-mpg.data", "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data")
# Out:
# Downloading data from https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data
# 32768/30286 [================================] - 0s 3us/step

# %%
# load the data into pandas
column_names = ['mpg', 'cyl', 'displacement', 'hp', 'weight', 'acceleration', 'year', 'country']
auto_df = pd.read_csv(data_file, na_values="?", comment="\t", sep=" ", skipinitialspace=True, names=column_names)

auto_df.head(5)
# Out:
#     mpg  cyl  displacement     hp  weight  acceleration  year  country
# 0  18.0    8         307.0  130.0  3504.0          12.0    70        1
# 1  15.0    8         350.0  165.0  3693.0          11.5    70        1
# 2  18.0    8         318.0  150.0  3436.0          11.0    70        1
# 3  16.0    8         304.0  150.0  3433.0          12.0    70        1
# 4  17.0    8         302.0  140.0  3449.0          10.5    70        1

# %%
# look for na values
auto_df.isna().sum()
# Out:
# mpg             0
# cyl             0
# displacement    0
# hp              6
# weight          0
# acceleration    0
# year            0
# country         0
# dtype: int64

# %%
# describe the data
auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cyl           398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   hp            392 non-null    float64
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   year          398 non-null    int64
#  7   country       398 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 25.0 KB

# %%
# drop the na data
auto_df = auto_df.dropna()

auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cyl           392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   hp            392 non-null    float64
#  4   weight        392 non-null    float64
#  5   acceleration  392 non-null    float64
#  6   year          392 non-null    int64
#  7   country       392 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 27.6 KB

# %%
# shuffle the data
auto_df = shuffle(auto_df, random_state=2)

# %%
# one hot the country column
auto_df = pd.get_dummies(auto_df, columns=['country'])

auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 56 to 170
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cyl           392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   hp            392 non-null    float64
#  4   weight        392 non-null    float64
#  5   acceleration  392 non-null    float64
#  6   year          392 non-null    int64
#  7   country_1     392 non-null    uint8
#  8   country_2     392 non-null    uint8
#  9   country_3     392 non-null    uint8
# dtypes: float64(5), int64(2), uint8(3)
# memory usage: 25.6 KB

# %%
# show the data
auto_df.head(5)
# Out:
#       mpg  cyl  displacement    hp  weight  acceleration  year  country_1  \
# 56   26.0    4          91.0  70.0  1955.0          20.5    71          1
# 71   19.0    3          70.0  97.0  2330.0          13.5    72          0
# 315  24.3    4         151.0  90.0  3003.0          20.1    80          1
# 181  33.0    4          91.0  53.0  1795.0          17.5    75          0
# 309  41.5    4          98.0  76.0  2144.0          14.7    80          0
#
#      country_2  country_3
# 56           0          0
# 71           0          1
# 315          0          0
# 181          0          1
# 309          1          0

# %%
# get the features and labels
feature_df = auto_df
label_df = feature_df.pop('mpg')

# split into train and test datasets
X_train, X_test, y_train, y_test = train_test_split(feature_df, label_df, test_size=0.2)

print("the train dataset is of shape {} and train label of shape{}".format(X_train.shape, y_train.shape))
print("the test dataset is of shape {} and test label of shape{}".format(X_test.shape, y_test.shape))
# Out:
# the train dataset is of shape (313, 9) and train label of shape(313,)
# the test dataset is of shape (79, 9) and test label of shape(79,)

# %%
# scale the data
# build the scaler
scaler = StandardScaler()

# fit the scaler on the training data
scaler.fit(X_train)

# transform the traning and test data
X_train = pd.DataFrame(scaler.transform(X_train))
X_test = pd.DataFrame(scaler.transform(X_test))

X_train.head(5)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.306410  0.292453 -0.102450  0.754840  0.791737  0.286114  0.804592
# 1  1.483177  1.183913  1.228124  0.899904 -0.566247  0.016374  0.804592
# 2 -0.870356 -1.107045 -0.980629 -1.179741 -0.015713 -0.523105 -1.242866
# 3 -0.870356 -0.790720 -0.421788 -0.434689  1.489080  1.634812  0.804592
# 4  0.306410  0.052813 -0.501622  0.104951  0.424714  0.555853  0.804592
#
#           7         8
# 0 -0.476918 -0.511954
# 1 -0.476918 -0.511954
# 2  2.096796 -0.511954
# 3 -0.476918 -0.511954
# 4 -0.476918 -0.511954

# %%
# build the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, input_shape=(9,), activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])

# compile the model
# model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
model.compile(loss='mse', optimizer='adam', metrics=['mae', 'mse'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 64)                640
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,865
# Trainable params: 4,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the model
history = model.fit(X_train, y_train, epochs=50, batch_size=20, validation_split=0.2)
# Out:
# Train on 250 samples, validate on 63 samples
# Epoch 1/50
# 250/250 [==============================] - 0s 107us/sample - loss: 5.4139 - mae: 1.7021 - mse: 5.4139 - val_loss: 14.6244 - val_mae: 2.6179 - val_mse: 14.6244
# Epoch 2/50
# 250/250 [==============================] - 0s 83us/sample - loss: 5.4392 - mae: 1.7092 - mse: 5.4392 - val_loss: 14.3909 - val_mae: 2.6118 - val_mse: 14.3909
# Epoch 3/50
# 250/250 [==============================] - 0s 84us/sample - loss: 5.3576 - mae: 1.6846 - mse: 5.3576 - val_loss: 14.7401 - val_mae: 2.6382 - val_mse: 14.7401
# Epoch 4/50
# 250/250 [==============================] - 0s 78us/sample - loss: 5.2552 - mae: 1.6807 - mse: 5.2552 - val_loss: 14.5659 - val_mae: 2.6235 - val_mse: 14.5659
# Epoch 5/50
# 250/250 [==============================] - 0s 81us/sample - loss: 5.2761 - mae: 1.6842 - mse: 5.2761 - val_loss: 14.3049 - val_mae: 2.6182 - val_mse: 14.3049
# Epoch 6/50
# 250/250 [==============================] - 0s 75us/sample - loss: 5.2190 - mae: 1.6711 - mse: 5.2190 - val_loss: 14.7321 - val_mae: 2.6142 - val_mse: 14.7321
# Epoch 7/50
# 250/250 [==============================] - 0s 80us/sample - loss: 5.1949 - mae: 1.6635 - mse: 5.1949 - val_loss: 14.5783 - val_mae: 2.6297 - val_mse: 14.5783
# Epoch 8/50
# 250/250 [==============================] - 0s 74us/sample - loss: 5.2357 - mae: 1.6738 - mse: 5.2357 - val_loss: 14.6223 - val_mae: 2.6188 - val_mse: 14.6223
# Epoch 9/50
# 250/250 [==============================] - 0s 73us/sample - loss: 5.2403 - mae: 1.6750 - mse: 5.2403 - val_loss: 14.3651 - val_mae: 2.6229 - val_mse: 14.3651
# Epoch 10/50
# 250/250 [==============================] - 0s 78us/sample - loss: 5.1799 - mae: 1.6700 - mse: 5.1799 - val_loss: 14.8830 - val_mae: 2.6414 - val_mse: 14.8830
# Epoch 11/50
# 250/250 [==============================] - 0s 80us/sample - loss: 5.2319 - mae: 1.6738 - mse: 5.2319 - val_loss: 14.2744 - val_mae: 2.6110 - val_mse: 14.2744
# Epoch 12/50
# 250/250 [==============================] - 0s 96us/sample - loss: 5.1265 - mae: 1.6567 - mse: 5.1265 - val_loss: 14.5926 - val_mae: 2.6309 - val_mse: 14.5926
# Epoch 13/50
# 250/250 [==============================] - 0s 90us/sample - loss: 5.2051 - mae: 1.6636 - mse: 5.2051 - val_loss: 14.3832 - val_mae: 2.6149 - val_mse: 14.3832
# Epoch 14/50
# 250/250 [==============================] - 0s 88us/sample - loss: 5.1716 - mae: 1.6658 - mse: 5.1716 - val_loss: 14.7793 - val_mae: 2.6572 - val_mse: 14.7793
# Epoch 15/50
# 250/250 [==============================] - 0s 84us/sample - loss: 5.0735 - mae: 1.6378 - mse: 5.0735 - val_loss: 14.4345 - val_mae: 2.6054 - val_mse: 14.4345
# Epoch 16/50
# 250/250 [==============================] - 0s 83us/sample - loss: 5.1633 - mae: 1.6586 - mse: 5.1633 - val_loss: 14.6824 - val_mae: 2.6331 - val_mse: 14.6824
# Epoch 17/50
# 250/250 [==============================] - 0s 82us/sample - loss: 5.1799 - mae: 1.6652 - mse: 5.1799 - val_loss: 14.3475 - val_mae: 2.5992 - val_mse: 14.3475
# Epoch 18/50
# 250/250 [==============================] - 0s 86us/sample - loss: 5.2789 - mae: 1.6851 - mse: 5.2789 - val_loss: 14.3914 - val_mae: 2.6013 - val_mse: 14.3914
# Epoch 19/50
# 250/250 [==============================] - 0s 85us/sample - loss: 5.0986 - mae: 1.6407 - mse: 5.0986 - val_loss: 14.6358 - val_mae: 2.6275 - val_mse: 14.6358
# Epoch 20/50
# 250/250 [==============================] - 0s 84us/sample - loss: 5.0756 - mae: 1.6411 - mse: 5.0756 - val_loss: 14.3718 - val_mae: 2.6127 - val_mse: 14.3718
# Epoch 21/50
# 250/250 [==============================] - 0s 90us/sample - loss: 5.0090 - mae: 1.6385 - mse: 5.0090 - val_loss: 14.6113 - val_mae: 2.6239 - val_mse: 14.6113
# Epoch 22/50
# 250/250 [==============================] - 0s 93us/sample - loss: 5.0685 - mae: 1.6628 - mse: 5.0685 - val_loss: 14.2396 - val_mae: 2.5974 - val_mse: 14.2396
# Epoch 23/50
# 250/250 [==============================] - 0s 96us/sample - loss: 5.0761 - mae: 1.6427 - mse: 5.0761 - val_loss: 14.4525 - val_mae: 2.6019 - val_mse: 14.4525
# Epoch 24/50
# 250/250 [==============================] - 0s 91us/sample - loss: 4.9975 - mae: 1.6343 - mse: 4.9975 - val_loss: 14.3705 - val_mae: 2.6185 - val_mse: 14.3705
# Epoch 25/50
# 250/250 [==============================] - 0s 89us/sample - loss: 5.0420 - mae: 1.6308 - mse: 5.0420 - val_loss: 14.4350 - val_mae: 2.5964 - val_mse: 14.4350
# Epoch 26/50
# 250/250 [==============================] - 0s 86us/sample - loss: 5.0444 - mae: 1.6370 - mse: 5.0444 - val_loss: 14.3613 - val_mae: 2.6122 - val_mse: 14.3613
# Epoch 27/50
# 250/250 [==============================] - 0s 88us/sample - loss: 5.0516 - mae: 1.6463 - mse: 5.0516 - val_loss: 14.5239 - val_mae: 2.6153 - val_mse: 14.5239
# Epoch 28/50
# 250/250 [==============================] - 0s 91us/sample - loss: 5.0358 - mae: 1.6383 - mse: 5.0358 - val_loss: 14.2673 - val_mae: 2.6136 - val_mse: 14.2673
# Epoch 29/50
# 250/250 [==============================] - 0s 88us/sample - loss: 5.2288 - mae: 1.6660 - mse: 5.2288 - val_loss: 14.5247 - val_mae: 2.6099 - val_mse: 14.5247
# Epoch 30/50
# 250/250 [==============================] - 0s 91us/sample - loss: 4.9929 - mae: 1.6271 - mse: 4.9929 - val_loss: 14.2874 - val_mae: 2.6119 - val_mse: 14.2874
# Epoch 31/50
# 250/250 [==============================] - 0s 89us/sample - loss: 4.8938 - mae: 1.6209 - mse: 4.8938 - val_loss: 14.7666 - val_mae: 2.6326 - val_mse: 14.7666
# Epoch 32/50
# 250/250 [==============================] - 0s 88us/sample - loss: 4.9160 - mae: 1.6248 - mse: 4.9160 - val_loss: 14.2816 - val_mae: 2.6001 - val_mse: 14.2816
# Epoch 33/50
# 250/250 [==============================] - 0s 87us/sample - loss: 4.9735 - mae: 1.6305 - mse: 4.9735 - val_loss: 14.5564 - val_mae: 2.6231 - val_mse: 14.5564
# Epoch 34/50
# 250/250 [==============================] - 0s 89us/sample - loss: 4.9213 - mae: 1.6188 - mse: 4.9213 - val_loss: 14.2818 - val_mae: 2.6068 - val_mse: 14.2818
# Epoch 35/50
# 250/250 [==============================] - 0s 83us/sample - loss: 4.8811 - mae: 1.6075 - mse: 4.8811 - val_loss: 14.5179 - val_mae: 2.6092 - val_mse: 14.5179
# Epoch 36/50
# 250/250 [==============================] - 0s 92us/sample - loss: 4.8890 - mae: 1.6151 - mse: 4.8890 - val_loss: 14.5581 - val_mae: 2.6302 - val_mse: 14.5581
# Epoch 37/50
# 250/250 [==============================] - 0s 85us/sample - loss: 4.8745 - mae: 1.6185 - mse: 4.8745 - val_loss: 14.4834 - val_mae: 2.6164 - val_mse: 14.4834
# Epoch 38/50
# 250/250 [==============================] - 0s 89us/sample - loss: 4.8595 - mae: 1.6044 - mse: 4.8595 - val_loss: 14.7019 - val_mae: 2.6260 - val_mse: 14.7019
# Epoch 39/50
# 250/250 [==============================] - 0s 88us/sample - loss: 4.8643 - mae: 1.6131 - mse: 4.8643 - val_loss: 14.4891 - val_mae: 2.6198 - val_mse: 14.4891
# Epoch 40/50
# 250/250 [==============================] - 0s 84us/sample - loss: 4.8633 - mae: 1.6057 - mse: 4.8633 - val_loss: 14.4606 - val_mae: 2.6119 - val_mse: 14.4606
# Epoch 41/50
# 250/250 [==============================] - 0s 87us/sample - loss: 4.7817 - mae: 1.5919 - mse: 4.7817 - val_loss: 14.3568 - val_mae: 2.5967 - val_mse: 14.3568
# Epoch 42/50
# 250/250 [==============================] - 0s 85us/sample - loss: 4.8630 - mae: 1.6134 - mse: 4.8630 - val_loss: 14.2083 - val_mae: 2.5963 - val_mse: 14.2083
# Epoch 43/50
# 250/250 [==============================] - 0s 84us/sample - loss: 4.7956 - mae: 1.5945 - mse: 4.7956 - val_loss: 14.5914 - val_mae: 2.6145 - val_mse: 14.5914
# Epoch 44/50
# 250/250 [==============================] - 0s 90us/sample - loss: 4.8842 - mae: 1.5976 - mse: 4.8842 - val_loss: 14.2505 - val_mae: 2.6087 - val_mse: 14.2505
# Epoch 45/50
# 250/250 [==============================] - 0s 86us/sample - loss: 4.7463 - mae: 1.5901 - mse: 4.7463 - val_loss: 14.7065 - val_mae: 2.6136 - val_mse: 14.7065
# Epoch 46/50
# 250/250 [==============================] - 0s 83us/sample - loss: 4.7996 - mae: 1.6020 - mse: 4.7996 - val_loss: 14.3561 - val_mae: 2.6111 - val_mse: 14.3561
# Epoch 47/50
# 250/250 [==============================] - 0s 90us/sample - loss: 4.8203 - mae: 1.6047 - mse: 4.8203 - val_loss: 14.6053 - val_mae: 2.6240 - val_mse: 14.6053
# Epoch 48/50
# 250/250 [==============================] - 0s 88us/sample - loss: 4.7919 - mae: 1.5881 - mse: 4.7919 - val_loss: 14.6086 - val_mae: 2.6179 - val_mse: 14.6086
# Epoch 49/50
# 250/250 [==============================] - 0s 84us/sample - loss: 4.8062 - mae: 1.6034 - mse: 4.8062 - val_loss: 14.5248 - val_mae: 2.6132 - val_mse: 14.5248
# Epoch 50/50
# 250/250 [==============================] - 0s 82us/sample - loss: 4.7531 - mae: 1.5876 - mse: 4.7531 - val_loss: 14.3711 - val_mae: 2.5960 - val_mse: 14.3711

# %%
# import matplotlib
import matplotlib.pyplot as plt 

# plot the history
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch

# plot
plt.figure()
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.plot(hist['epoch'], hist['mae'], label=['Train Error'])
plt.plot(hist['epoch'], hist['val_mae'], label=['Val Error'])
plt.legend()
plt.ylim([0, 5])

plt.figure()
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.plot(hist['epoch'], hist['mse'], label=['Train Error'])
plt.plot(hist['epoch'], hist['val_mse'], label=['Val Error'])
plt.legend()
plt.ylim([0, 20])
# Out:
# (0.0, 20.0)

# %%
history
